# %%
import numpy as np
import pandas as pd
from datetime import timedelta, datetime, date

# %% [markdown]
# #### Feed the downloaded file here

# %%
df = pd.read_csv(r'C:\Users\user\Downloads\transactions2.csv')

# %%
df.columns = df.columns.str.strip()
df.head()
# Out:
#              Date  Folio Number  \
# 0      2023-02-10    8359375/61
# 1      2023-02-06    8359375/61
# 2      2023-02-06    8359375/61
# 3      2023-02-06  499159051935
# 4      2023-02-06   91024256445
#
#                                     Name of the Fund Order    Units  \
# 0    ICICI Prudential Commodities Growth Direct Plan   buy  131.713
# 1    ICICI Prudential Commodities Growth Direct Plan   buy  709.436
# 2  ICICI Prudential Infrastructure Growth Direct ...   buy  141.476
# 3             Nippon India Liquid Growth Direct Plan   buy    7.340
# 4                     Axis Liquid Growth Direct Plan   buy    6.061
#
#          NAV  Current Nav  Amount (INR)
# 0    28.0900      28.0900       3699.82
# 1    28.1900      28.0900      19999.00
# 2   106.0200     106.6000      14999.25
# 3  5449.0575    5455.7269      39998.00
# 4  2474.5770    2477.6146      14999.25

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df2 = df

# %% [markdown]
# #### Prevent all the liquid fund from showing

# %%
df = df[~df['Name of the Fund'].str.contains("Kuvera|Liquid|Money|Gilt|Cash|Bond|Debt|Short|Gold|Securities|Duration|Income")]
##remove the upper line in case performance of all the mutual fund is required
df = df.loc[~df['Order'].str.contains("sell")]

# %%
today = pd.to_datetime(date.today())

# %% [markdown]
# #### Control the number of days to look behind / calculate the Xirr for. for three years we take 365*3 = 1095 days

# %%
df = df.loc[df['Date'] > (pd.to_datetime(date.today() - timedelta(days = 4000)))]

# %%
mf_name = df['Name of the Fund'].unique()

# %% [markdown]
# #### See the list of all the mutual funds

# %%
mf_name
# Out:
# array(['ICICI Prudential Commodities Growth Direct Plan',
#        'ICICI Prudential Infrastructure Growth Direct Plan',
#        'Axis Small Cap Growth Direct Plan',
#        'Quant Mid Cap Growth Direct Plan', 'Quant Tax Growth Direct Plan',
#        'Quant Small Cap Growth Direct Plan',
#        'Quant Infrastructure Growth Direct Plan',
#        'Quant Active Growth Direct Plan',
#        'PGIM India Midcap Opportunities Growth Direct Plan',
#        'Canara Robeco Small Cap Growth Direct Plan',
#        'Quant Quantamental Growth Direct Plan',
#        'Quant Flexi Cap Growth Direct Plan',
#        'ICICI Prudential Technology Growth Direct Plan',
#        'PGIM India Flexi Cap Growth Direct Plan',
#        'Mirae Asset Emerging Bluechip Growth Direct Plan',
#        'Mirae Asset Tax Saver Growth Direct Plan',
#        'Tata Digital India Growth Direct Plan',
#        'Axis Growth Opportunities Growth Direct Plan',
#        'Axis Mid Cap Growth Direct Plan',
#        'Parag Parikh Flexi Cap Growth Direct Plan',
#        'Quant Large & Mid Cap Growth Direct Plan',
#        'Axis Focused 25 Growth Direct Plan',
#        'ICICI Prudential Nifty 50 Index Growth Direct Plan',
#        'PGIM India Global Equity Opportunities Growth Direct Plan',
#        'ICICI Prudential US Bluechip Equity Growth Direct Plan',
#        'Axis Flexi Cap Growth Direct Plan',
#        'Mirae Asset Healthcare Growth Direct Plan',
#        'Motilal Oswal Nasdaq 100 FoF Growth Direct Plan',
#        'LIC MF Index Sensex Growth Direct Plan',
#        'Axis Bluechip Growth Direct Plan',
#        'Canara Robeco Bluechip Equity Growth Direct Plan',
#        'DSP Healthcare Growth Direct Plan',
#        'Canara Robeco Emerging Equities Growth Direct Plan',
#        'Motilal Oswal Nifty Bank Index Growth Direct Plan',
#        'Principal Emerging Bluechip Growth Direct Plan',
#        'SBI Small Cap Growth Direct Plan',
#        'Aditya Birla Sun Life Banking & Financial Services Growth Direct Plan',
#        'SBI Banking & Financial Services Growth Direct Plan',
#        'ICICI Prudential Banking & Financial Services Growth Direct Plan',
#        'Kotak Emerging Equity Growth Direct Plan',
#        'Franklin India Smaller Companies Growth Direct Plan',
#        'L&T Emerging Businesses Growth Direct Plan',
#        'Sundaram Large & Mid Cap Growth Direct Plan',
#        'Nippon India Large Cap Growth Direct Plan',
#        'DSP Small Cap Growth Direct Plan',
#        'Axis Long Term Equity Growth Direct Plan',
#        'Nippon India Small Cap Growth Direct Plan',
#        'Principal Emerging Bluechip Regular Half Yearly IDCW Payout Plan',
#        'Principal Emerging Bluechip Regular Growth Plan',
#        'Sundaram Large & Mid Cap Regular IDCW Payout Plan',
#        'Sundaram Large & Mid Cap Regular Growth Plan',
#        'IDBI Equity Advantage Regular Growth Plan',
#        'DSP Tax Saver Growth Direct Plan',
#        'Mirae Asset Tax Saver Regular Growth Plan',
#        'Mirae Asset Emerging Bluechip Regular Growth Plan',
#        'Sundaram Tax Saving Regular Growth Plan',
#        'Aditya Birla Sun Life Saving Growth Direct Plan',
#        'ICICI Prudential Long Term Equity Growth Plan',
#        'L&T India Value Growth Plan',
#        'DSP Natural Resources & New Energy Growth Direct Plan'],
#       dtype=object)

# %%
df['Amount (INR)'] = df['Amount (INR)']*-1

# %%
df.head()
# Out:
#         Date Folio Number                                   Name of the Fund  \
# 0 2023-02-10   8359375/61    ICICI Prudential Commodities Growth Direct Plan
# 1 2023-02-06   8359375/61    ICICI Prudential Commodities Growth Direct Plan
# 2 2023-02-06   8359375/61  ICICI Prudential Infrastructure Growth Direct ...
# 7 2023-02-01  91024256445                  Axis Small Cap Growth Direct Plan
# 9 2023-02-01   5102363071                   Quant Mid Cap Growth Direct Plan
#
#   Order    Units      NAV  Current Nav  Amount (INR)
# 0   buy  131.713   28.090      28.0900      -3699.82
# 1   buy  709.436   28.190      28.0900     -19999.00
# 2   buy  141.476  106.020     106.6000     -14999.25
# 7   buy   14.116   70.840      72.0500       -999.95
# 9   buy  361.200  141.189     142.8888     -50997.45

# %% [markdown]
# #### Create the  function that calculates Xirr ( funciton copied from https://github.com/SunilVeeravalli/XIRR_in_Python/blob/main/xirr.py )

# %%
min_rate = 0
max_rate = 0
def npv(seq_of_rates: np.array, data: pd.DataFrame) -> tuple:
    global min_rate
    global max_rate
    
    for a_rate in seq_of_rates:
        max_date = data['Date'].max()
        data['npv'] = data['Amount'] * ((1 + (a_rate / 100)) ** ((max_date - data['Date']).dt.days / 365))
        
        if data['Amount'].sum() > 0:
            if data['npv'].sum() > 0:
                min_rate = a_rate
            else:
                max_rate = a_rate
                break
        else:
            if data['npv'].sum() < 0:
                min_rate = a_rate
            else:
                max_rate = a_rate
                break
    
    return min_rate, max_rate


def xirr(data: pd.DataFrame) -> float:
    # Finding out which column contains Date and Amount
    try:
        data.iloc[:, 0].astype(float)
        col_names = ['Amount', 'Date']
    except Exception as _:
        col_names = ['Date', 'Amount']
    
    # Renaming the columns accordingly and converting to correct data types
    data.columns = col_names
    data = data.assign(Date = pd.to_datetime(arg = data['Date'], infer_datetime_format = True, dayfirst = True).dt.date,
                       Amount = data['Amount'].astype(float))
    
    if data['Amount'].sum() > 0:
        step_values = [100, 10, 1, 0.01, 0.001, 0.0001]
        stop = 10000
    else:
        step_values = [-100, -10, -1, -0.01, -0.001, -0.0001]
        stop = -10000
    
    start = 0
    for i in range(len(step_values)):
        seq_of_rates = np.arange(start = start, stop = stop, step = step_values[i])
        start, stop = npv(seq_of_rates, data)
    
    return (start + stop) / 2

# %%
solution = []
mf= []
for i in range(0,len(mf_name)):
    mf = df[df['Name of the Fund'] == mf_name[i]]
    mf = mf.append(pd.DataFrame({'Date': today, 'Amount (INR)':mf.Units.sum() * mf['Current Nav'].unique() }), 
                   ignore_index = True, sort = True)
    ready_df = mf[['Date','Amount (INR)']]
    solution.append(xirr(ready_df))

# %%
final_df = pd.DataFrame(list(zip(mf_name.tolist(),solution)))

# %%
final_df.columns = ['Name of the Fund', 'Xirr']

# %% [markdown]
# ### See the final performance of the mutual fund sorted based on the overall Xirr

# %%
final_df.sort_values('Xirr', ascending = False)
# Out:
#                                      Name of the Fund      Xirr
# 2                   Axis Small Cap Growth Direct Plan  30.03705
# 33  Motilal Oswal Nifty Bank Index Growth Direct Plan  26.84635
# 35                   SBI Small Cap Growth Direct Plan  24.48245
# 39           Kotak Emerging Equity Growth Direct Plan  22.52455
# 18                    Axis Mid Cap Growth Direct Plan  22.45865
# 32  Canara Robeco Emerging Equities Growth Direct ...  21.57945
# 40  Franklin India Smaller Companies Growth Direct...  20.75735
# 22  ICICI Prudential Nifty 50 Index Growth Direct ...  20.29165
# 20           Quant Large & Mid Cap Growth Direct Plan  19.81735
# 37  SBI Banking & Financial Services Growth Direct...  19.62815
# 28             LIC MF Index Sensex Growth Direct Plan  19.29275
# 14   Mirae Asset Emerging Bluechip Growth Direct Plan  19.02245
# 5                  Quant Small Cap Growth Direct Plan  18.93855
# 46          Nippon India Small Cap Growth Direct Plan  18.28065
# 19          Parag Parikh Flexi Cap Growth Direct Plan  18.19055
# 34     Principal Emerging Bluechip Growth Direct Plan  17.81225
# 36  Aditya Birla Sun Life Banking & Financial Serv...  17.67235
# 25                  Axis Flexi Cap Growth Direct Plan  16.36565
# 24  ICICI Prudential US Bluechip Equity Growth Dir...  15.92075
# 44                   DSP Small Cap Growth Direct Plan  15.34215
# 29                   Axis Bluechip Growth Direct Plan  15.31235
# 48    Principal Emerging Bluechip Regular Growth Plan  12.44055
# 49  Sundaram Large & Mid Cap Regular IDCW Payout Plan -11.33325
# 50       Sundaram Large & Mid Cap Regular Growth Plan  10.60905
# 51          IDBI Equity Advantage Regular Growth Plan   8.46065
# 52                   DSP Tax Saver Growth Direct Plan  13.59485
# 53          Mirae Asset Tax Saver Regular Growth Plan  12.81175
# 54  Mirae Asset Emerging Bluechip Regular Growth Plan  13.01725
# 55            Sundaram Tax Saving Regular Growth Plan   9.73925
# 56    Aditya Birla Sun Life Saving Growth Direct Plan   6.44165
# 57      ICICI Prudential Long Term Equity Growth Plan  12.12165
# 58                        L&T India Value Growth Plan  10.46465
# 59  DSP Natural Resources & New Energy Growth Dire...  12.66215

# %%
df_temp = df.loc[df['Name of the Fund']=='Quant Small Cap Growth Direct Plan']

# %%
df_temp.head()
# Out:
#          Date Folio Number                    Name of the Fund Order   Units  \
# 13 2023-01-25  51022358821  Quant Small Cap Growth Direct Plan   buy  32.772
# 42 2022-12-28   5102363071  Quant Small Cap Growth Direct Plan   buy  33.123
# 51 2022-12-23   5102363071  Quant Small Cap Growth Direct Plan   buy  35.416
# 71 2022-11-28   5102363071  Quant Small Cap Growth Direct Plan   buy  33.310
# 93 2022-10-28   5102363071  Quant Small Cap Growth Direct Plan   buy  34.939
#
#          NAV  Current Nav  Amount (INR)
# 13  152.5608     151.2203      -4999.75
# 42  150.9439     151.2203      -4999.75
# 51  141.1731     151.2203      -4999.75
# 71  150.0987     151.2203      -4999.75
# 93  143.1010     151.2203      -4999.75

# %%
df_temp.sort_values(by=['Date'],axis=0, ascending=True, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_temp
# Out:
#           Date Folio Number                    Name of the Fund Order   Units  \
# 713 2020-10-12   5102363071  Quant Small Cap Growth Direct Plan   buy  16.121
# 696 2020-11-10   5102363071  Quant Small Cap Growth Direct Plan   buy  16.111
# 689 2020-11-26   5102363071  Quant Small Cap Growth Direct Plan   buy  15.163
# 670 2020-12-04   5102363071  Quant Small Cap Growth Direct Plan   buy  14.420
# 661 2020-12-10   5102363071  Quant Small Cap Growth Direct Plan   buy  14.125
# ..         ...          ...                                 ...   ...     ...
# 93  2022-10-28   5102363071  Quant Small Cap Growth Direct Plan   buy  34.939
# 71  2022-11-28   5102363071  Quant Small Cap Growth Direct Plan   buy  33.310
# 51  2022-12-23   5102363071  Quant Small Cap Growth Direct Plan   buy  35.416
# 42  2022-12-28   5102363071  Quant Small Cap Growth Direct Plan   buy  33.123
# 13  2023-01-25  51022358821  Quant Small Cap Growth Direct Plan   buy  32.772
#
#           NAV  Current Nav  Amount (INR)
# 713   62.0278     151.2203       -999.95
# 696   62.0664     151.2203       -999.95
# 689   65.9467     151.2203       -999.95
# 670   69.3449     151.2203       -999.95
# 661   70.7935     151.2203       -999.95
# ..        ...          ...           ...
# 93   143.1010     151.2203      -4999.75
# 71   150.0987     151.2203      -4999.75
# 51   141.1731     151.2203      -4999.75
# 42   150.9439     151.2203      -4999.75
# 13   152.5608     151.2203      -4999.75
#
# [80 rows x 8 columns]
